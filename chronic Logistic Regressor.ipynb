# %% [markdown]
# <a href="https://colab.research.google.com/github/JatinAllamsetty27/Ideas-and-Implementations/blob/main/chronic%20Logistic%20Regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('chronic.csv')
data
# Out:
#        Bp     Sg   Al   Su  Rbc    Bu   Sc     Sod   Pot  Hemo    Wbcc  Rbcc  \
# 0    80.0  1.020  1.0  0.0  1.0  36.0  1.2  137.53  4.63  15.4  7800.0  5.20
# 1    50.0  1.020  4.0  0.0  1.0  18.0  0.8  137.53  4.63  11.3  6000.0  4.71
# 2    80.0  1.010  2.0  3.0  1.0  53.0  1.8  137.53  4.63   9.6  7500.0  4.71
# 3    70.0  1.005  4.0  0.0  1.0  56.0  3.8  111.00  2.50  11.2  6700.0  3.90
# 4    80.0  1.010  2.0  0.0  1.0  26.0  1.4  137.53  4.63  11.6  7300.0  4.60
# ..    ...    ...  ...  ...  ...   ...  ...     ...   ...   ...     ...   ...
# 395  80.0  1.020  0.0  0.0  1.0  49.0  0.5  150.00  4.90  15.7  6700.0  4.90
# 396  70.0  1.025  0.0  0.0  1.0  31.0  1.2  141.00  3.50  16.5  7800.0  6.20
# 397  80.0  1.020  0.0  0.0  1.0  26.0  0.6  137.00  4.40  15.8  6600.0  5.40
# 398  60.0  1.025  0.0  0.0  1.0  50.0  1.0  135.00  4.90  14.2  7200.0  5.90
# 399  80.0  1.025  0.0  0.0  1.0  18.0  1.1  141.00  3.50  15.8  6800.0  6.10
#
#      Htn  Class
# 0    1.0      1
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=100,random_state=0)
x=data.iloc[:,:-1]
y=data.iloc[:,:-1]

regressor.fit(x,y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
RandomForestRegressor(bootstrap=True,criterion='bp',max_depth=None,
                      max_features='auto',max_leaf_nodes=None,
                      min_impurity_decrease=0.0,
                      min_samples_leaf=1,min_samples_split=2,
                      min_weight_fraction_leaf=0.0,n_estimators=100,n_jobs=1,
                      oob_score=False,random_state=0,verbose=0,warm_start=False)
# Out:
# RandomForestRegressor(criterion='bp', n_jobs=1, random_state=0)

# %%
y_pred=regressor.predict(np.array([6.5]).reshape(1,1,))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-01dbfed97d40> in <module>
# ----> 1 y_pred=regressor.predict(np.array([6.5]).reshape(1,1,))
#
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     969         check_is_fitted(self)
#     970         # Check data
# --> 971         X = self._validate_X_predict(X)
#     972
#     973         # Assign chunk of trees to jobs
#
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     577         Validate X whenever one tries to predict, apply, predict_proba."""
#     578         check_is_fitted(self)
# ...
